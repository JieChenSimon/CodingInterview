# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 非虚拟节点法，纯原链表删除元素
from typing import Optional
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def removeElements(self, head: Optional[ListNode], val: int) -> Optional[ListNode]:
        """
        LeetCode 203: 移除链表元素
        删除所有值为 val 的节点
        """
        # 删除头节点
        while head is not None and head.val == val:  # 注意这里是 while 不是 if
            head = head.next
            # Python 有自动垃圾回收,不需要手动 delete
        
        # 删除非头节点
        cur = head #cur是定义的临时指针，从head开始的；因为只要将cur的下一个节点指向cur.next.next,所以cur是从head开始，而不是从head.next开始。且cur和cur.next不能为空，不然报空指针错误
        while cur is not None and cur.next is not None:
            if cur.next.val == val:
                cur.next = cur.next.next
                # Python 有自动垃圾回收,不需要手动 delete
            else: #如不等于val，则继续向下走，看看是不是等于val
                cur = cur.next
        
        return head

# %%
# 虚拟头节点法，即增加一个虚拟的头节点，那么原先的头节点和非头节点都可以被当成非头节点一样处理了，只要将cur的下一个节点指向cur.next.next
# Definition for singly-linked list. 这个ListNode的定义leetcode有时候默认就有
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

from typing import Optional

class Solution:
    def removeElements(self, head: Optional[ListNode], val: int) -> Optional[ListNode]:
        # 创建虚拟头部节点以简化删除过程，并将dummy这个节点的next指向之前的头节点head
        dummy_head = ListNode(next = head)
        
        # 遍历列表并删除值为val的节点
        current = dummy_head #还是要顶一个临时指针，是从dummy_head开始，而不是dummy_head.next
        while current.next:#判读是否为空
            if current.next.val == val:
                current.next = current.next.next
            else:
                current = current.next
        
        return dummy_head.next

# %%
# 2025-11-17
# 核心技术就是构造一个新的临时节点，作为新的虚拟头节点，使得之前的旧的头结点能够变成和非头节点一样处理。
class ListNode:
    def __init__(self, val = 0, next = None):
        self.val = val
        self.next = next

class MyLinkedList:
    def __init__(self):
        self.head = None
        self.size = 0
    def removeTargetValNode(self, val: int, head: ListNode):
        #	这一行创建了一个 虚拟头节点 (dummy node)，它的 next 指向真正的头节点 head。
        dummy_head = ListNode(next = head)

        curr = dummy_head
        # 开始从虚拟头节点出发遍历链表。不从 原本head 开始是因为我们要“保证 prev（前一个节点）始终存在”
        while curr.next:
            # 如果写成 while curr，当curr 是最后一个节点 (curr.next == None)，你还去读 curr.next.val 就会报错。
            if curr.next.val == val:
                # 可以用指针指向理解，curr → node_A → node_B → ...；
                curr.next = curr.next.next
                self.size -= 1
            else:
                curr = curr.next
        return dummy_head.next
            

if __name__ == "__main__":
    # 实例化一个链表
    myLinkedList = MyLinkedList()
    # 加值

    myLinkedList.head = ListNode(1)
    myLinkedList.head.next = ListNode(2)
    myLinkedList.head.next.next = ListNode(3)
    myLinkedList.size = 3

    # 具体核心算法-虚拟节点
    myLinkedList.removeTargetValNode(val = 2, head = myLinkedList.head)
    print("myLinkedList.head:",myLinkedList.head.val)
    print("myLinkedList.head.next:",myLinkedList.head.next.val)
    print("size of LinkedList:", myLinkedList.size)



# 判断不是while curr了，而是while curr.next:
# Out:
# myLinkedList.head: 1
# myLinkedList.head.next: 3
# size of LinkedList: 2

# %% [markdown]
# ## 类似题目
#
# ![image.png](attachment:image.png)
