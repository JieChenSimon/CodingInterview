# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution(object):
    def reverseList(self, head):
        """
        :type head: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        pre = None
    # 口诀：空手等待 —— 反转后的链表头我暂时用 None 占位。

        curr = head
        # 口诀：抓住当前 —— 用 curr 抓住原链表的第一个节点。

        while curr:
            # 口诀：有节点就干 —— curr 不空就继续反转。

            tmp = curr.next
            # 口诀①：保后路 —— 先把下一节点存到 tmp！

            curr.next = pre
            # 口诀②：反箭头 —— 把 curr 的箭头指向 pre，实现“反转”。

            # 下面这里必须先移动pre，后移动curr。
            # 如是
            # curr = tmp这里的curr的值已经改了，就没有办法移动pre到之前curr的node了
            # pre = curr
            pre = curr
            # 口诀③：接当前 —— 用 pre 接住已经反转好的新头。

            curr = tmp
            # 口诀④：往前走 —— curr 前进到下一节点继续处理。

        return pre
    # 口诀：交出头 —— 最终 pre 就是整个链表反过来的新头。
